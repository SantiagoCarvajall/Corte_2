# %% [markdown]
# **20 COSAS QUE NO SE PUEDEN HACER EN COLAB**

# %% [markdown]
# 1. hosting de archivos, entrega de contenido multimedia o cualquier oferta de servicios web no relacionada con el procesamiento interactivo con Colab
#
# ![1.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# 2. descarga de torrents o intercambio de archivos entre pares
#
#
# ![2.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# 3. utilización de un escritorio remoto o SSH
#
# ![OIP.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# 4. conexión a proxies remotos
#
# ![R (4).png](data:image/png;base64,...)

# %% [markdown]
# 5. minería de criptomonedas
#
# ![CRIPTOMONEDAS.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 6. ejecución de ataques de denegación del servicio
#
# ![OIP (1).jfif](data:image/jpeg;base64,...)

# %% [markdown]
# 7.robo de contraseñas
# ![sd.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# 8. utilización de varias cuentas para evitar las restricciones de acceso o el uso de recursos
#
# ![Captura de pantalla 2022-11-10 163905.png](data:image/png;base64,...)

# %% [markdown]
# 9. creación de deepfakes
#
# ![eem6rojxyaqlgzg_1_crop1596759447906.jpg_1935743484.webp](data:image/webp;base64,...)

# %% [markdown]
# 10. Trabajar e importar librerias como tkinter
#
# ![tkinter1.png](data:image/png;base64,...)

# %% [markdown]
# 11. Ejecutar archivo python directamente desde colab, No hay soporte para la reproducibilidad
#
# ![OIP (2).jfif](data:image/jpeg;base64,...)

# %% [markdown]
# 12. No cuenta con programación de bloc de notas, a diferencia de visual studio code
#
# ![que-es-el-bloc-de-notas3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 13. No hay soporte para editores colaborativos
#
# ![R (3).jfif](data:image/jpeg;base64,...)

# %% [markdown]
# 14. Soporte de entorno virtual, Colab ni siquiera admite o utiliza venvs de forma nativa
#
# ![OIP (3).jfif](data:image/jpeg;base64,...)

# %% [markdown]
# 15. Visor de datos, Colab no cuenta con visor de datos
#
# ![Click-Get-to-download-and-install-Diagnostic-Data-Viewer-app.png](data:image/png;base64,...)

# %% [markdown]
# 16. ahorro y almacenamiento: Los archivos cargados se eliminan cuando se reinicia la sesión porque Google Colab no proporciona una función de almacenamiento persistente. Por lo tanto, si el dispositivo está apagado, los datos pueden perderse
#
# ![OIP (4).jfif](data:image/jpeg;base64,...)

# %% [markdown]
# 17. Colab tiene aprovisionamiento dinámico de recursos, lo que significa que no usa el Gpu Y cpu interno si no uno externo
#
# ![cpu-gpu.webp](data:image/webp;base64,...)

# %% [markdown]
# 18. Hay límites de tiempo, por lo que no puede usarlo todo el tiempo sin interrupciones. aproximadamente 12 horas de tiempo de ejecución
#
#
# ![OIP (5).jfif](data:image/jpeg;base64,...)

# %% [markdown]
# 19. Cuenta con limite de uso de GPU por sesión
#
# ![OIP (6).jfif](data:image/jpeg;base64,...)

# %% [markdown]
# 20. Python 2 ya no se admite en Colab, no se puede ejecutar python 2 en colab
#
#
# ![hqdefault.jpg](data:image/jpeg;base64,...)
